# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
图片相似性分析工具 - 定制版
根据指定路径自动分析图片相似性
"""

import os
import argparse
from PIL import Image
import imagehash
import numpy as np
import cv2
from collections import defaultdict
import json
from datetime import datetime
import shutil

class ImageSimilarityAnalyzer:
    def __init__(self, hash_size=8, highfreq_factor=4, image_scale=64):
        """
        初始化图片相似性分析器
        
        Args:
            hash_size: 哈希值大小
            highfreq_factor: 高频因子（用于pHash）
            image_scale: 图像缩放大小（用于wHash）
        """
        self.hash_size = hash_size
        self.highfreq_factor = highfreq_factor
        self.image_scale = image_scale
        self.supported_formats = ('.png', '.jpg', '.jpeg', '.gif', '.bmp', '.tiff')
        
    def is_image_file(self, file_path):
        """检查文件是否为支持的图片格式"""
        return file_path.lower().endswith(self.supported_formats)
    
    def get_image_paths(self, folder_path):
        """获取文件夹中所有图片的路径"""
        image_paths = []
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                if self.is_image_file(file_path):
                    image_paths.append(file_path)
        return image_paths
    
    def calculate_image_hashes(self, image_path):
        """
        计算图片的多种哈希值
        
        Returns:
            dict: 包含各种哈希值的字典
        """
        try:
            # 使用PIL打开图片
            with Image.open(image_path) as img:
                # 转换为RGB模式（处理透明度）
                if img.mode in ('RGBA', 'LA'):
                    background = Image.new(img.mode[:-1], img.size, (255, 255, 255))
                    background.paste(img, img.split()[-1])
                    img = background
                else:
                    img = img.convert('RGB')
                
                # 计算各种哈希值
                hashes = {
                    'ahash': str(imagehash.average_hash(img, hash_size=self.hash_size)),
                    'phash': str(imagehash.phash(img, hash_size=self.hash_size, 
                                               highfreq_factor=self.highfreq_factor)),
                    'dhash': str(imagehash.dhash(img, hash_size=self.hash_size)),
                    'whash': str(imagehash.whash(img, hash_size=self.hash_size, 
                                               image_scale=self.image_scale)),
                    'colorhash': str(imagehash.colorhash(img))
                }
                
                # 获取图片基本信息
                info = {
                    'width': img.width,
                    'height': img.height,
                    'mode': img.mode,
                    'file_size': os.path.getsize(image_path)
                }
                
                return {
                    'hashes': hashes,
                    'info': info,
                    'success': True
                }
                
        except Exception as e:
            print(f"计算图片哈希值失败 {image_path}: {str(e)}")
            return {'success': False, 'error': str(e)}
    
    def hamming_distance(self, hash1, hash2):
        """计算两个哈希值之间的汉明距离"""
        if len(hash1) != len(hash2):
            return float('inf')
        return sum(c1 != c2 for c1, c2 in zip(hash1, hash2))
    
    def calculate_similarity_score(self, hash1, hash2):
        """
        计算相似度分数（0-1之间，1表示完全相同）
        
        Args:
            hash1, hash2: 两个哈希字符串
        """
        distance = self.hamming_distance(hash1, hash2)
        max_distance = len(hash1)
        return 1 - (distance / max_distance)
    
    def analyze_similarity(self, target_folder, reference_folder, output_folder, threshold=0.7):
        """
        分析图片相似性并输出差异图片
        
        Args:
            target_folder: 要比较的图片文件夹
            reference_folder: 参考图片文件夹
            output_folder: 差异图片输出文件夹
            threshold: 相似度阈值
        """
        print("="*60)
        print("图片相似性分析工具 - 开始分析")
        print("="*60)
        
        # 验证路径
        paths = {
            '目标文件夹': target_folder,
            '参考文件夹': reference_folder,
            '输出文件夹': output_folder
        }
        
        for name, path in paths.items():
            if not os.path.exists(path):
                if name == '输出文件夹':
                    os.makedirs(path, exist_ok=True)
                    print(f"创建 {name}: {path}")
                else:
                    print(f"错误: {name} 不存在 - {path}")
                    return
        
        # 获取参考图片
        print(f"\n获取参考图片 ({reference_folder})...")
        reference_paths = self.get_image_paths(reference_folder)
        if not reference_paths:
            print("错误: 参考文件夹中未找到任何图片")
            return
        print(f"找到 {len(reference_paths)} 张参考图片")
        
        # 获取目标图片
        print(f"\n获取目标图片 ({target_folder})...")
        target_paths = self.get_image_paths(target_folder)
        if not target_paths:
            print("错误: 目标文件夹中未找到任何图片")
            return
        print(f"找到 {len(target_paths)} 张目标图片")
        
        # 计算参考图片哈希值
        print(f"\n计算参考图片哈希值...")
        reference_data = {}
        for i, img_path in enumerate(reference_paths):
            print(f"处理参考图片 {i+1}/{len(reference_paths)}: {os.path.basename(img_path)}")
            result = self.calculate_image_hashes(img_path)
            if result['success']:
                reference_data[img_path] = result
        
        if not reference_data:
            print("错误: 没有成功处理任何参考图片")
            return
        
        # 计算目标图片哈希值
        print(f"\n计算目标图片哈希值...")
        target_data = {}
        for i, img_path in enumerate(target_paths):
            print(f"处理目标图片 {i+1}/{len(target_paths)}: {os.path.basename(img_path)}")
            result = self.calculate_image_hashes(img_path)
            if result['success']:
                target_data[img_path] = result
        
        if not target_data:
            print("错误: 没有成功处理任何目标图片")
            return
        
        # 分析相似性
        print(f"\n分析图片相似性...")
        results = {
            'reference_images': list(reference_data.keys()),
            'similarity_scores': {},
            'dissimilar_images': [],
            'similar_groups': defaultdict(list),
            'analysis_stats': {}
        }
        
        # 对每张目标图片计算与参考图片的平均相似度
        for img_path in target_data:
            avg_similarity = 0
            hash_scores = {}
            
            for ref_img, ref_data in reference_data.items():
                img_hashes = target_data[img_path]['hashes']
                ref_hashes = ref_data['hashes']
                
                # 计算各种哈希算法的相似度
                scores = {}
                for hash_type in ref_hashes:
                    if hash_type in img_hashes:
                        scores[hash_type] = self.calculate_similarity_score(
                            ref_hashes[hash_type], img_hashes[hash_type]
                        )
                
                # 使用多种哈希算法的平均值作为最终分数
                if scores:
                    ref_score = sum(scores.values()) / len(scores)
                    hash_scores[ref_img] = {
                        'overall': ref_score,
                        'details': scores
                    }
            
            # 计算所有参考图片的平均相似度
            if hash_scores:
                overall_scores = [hs['overall'] for hs in hash_scores.values()]
                final_score = sum(overall_scores) / len(overall_scores)
                
                results['similarity_scores'][img_path] = {
                    'overall': final_score,
                    'by_reference': hash_scores
                }
                
                # 根据相似度分组
                if final_score >= 0.95:
                    results['similar_groups']['very_similar'].append(img_path)
                elif final_score >= 0.85:
                    results['similar_groups']['similar'].append(img_path)
                elif final_score >= 0.70:
                    results['similar_groups']['somewhat_similar'].append(img_path)
                else:
                    results['similar_groups']['dissimilar'].append(img_path)
                    results['dissimilar_images'].append(img_path)
        
        # 生成统计信息
        results['analysis_stats'] = {
            'total_target_images': len(target_data),
            'reference_count': len(reference_data),
            'dissimilar_count': len(results['dissimilar_images']),
            'similarity_distribution': {
                group: len(images) for group, images in results['similar_groups'].items()
            },
            'analysis_time': datetime.now().isoformat()
        }
        
        # 显示分析结果
        self.display_results(results)
        
        # 复制差异图片到输出文件夹
        self.copy_dissimilar_images(results, output_folder, threshold)
        
        # 保存报告
        self.save_report(results, output_folder)
        
        print(f"\n" + "="*60)
        print("分析完成！")
        print(f"差异图片已保存到: {output_folder}")
        print("="*60)
        
        return results
    
    def display_results(self, results):
        """显示分析结果"""
        print(f"\n📊 分析结果摘要")
        print("-" * 40)
        
        stats = results['analysis_stats']
        print(f"总目标图片数量: {stats['total_target_images']}")
        print(f"参考图片数量: {stats['reference_count']}")
        print(f"差异较大的图片数量: {stats['dissimilar_count']}")
        print()
        
        print(f"🔍 相似度分布:")
        for group, count in stats['similarity_distribution'].items():
            if count > 0:
                group_name = {
                    'very_similar': '高度相似 (≥95%)',
                    'similar': '相似 (85%-95%)',
                    'somewhat_similar': '有些相似 (70%-85%)',
                    'dissimilar': '差异较大 (<70%)'
                }.get(group, group)
                print(f"  {group_name}: {count} 张")
        
        if results['dissimilar_images']:
            print()
            print(f"❌ 差异较大的图片:")
            for i, img_path in enumerate(results['dissimilar_images'][:10]):  # 只显示前10个
                score = results['similarity_scores'][img_path]['overall']
                print(f"  {i+1}. {os.path.basename(img_path)} (相似度: {score:.3f})")
            if len(results['dissimilar_images']) > 10:
                print(f"  ... 还有 {len(results['dissimilar_images'])-10} 张")
    
    def copy_dissimilar_images(self, results, output_folder, threshold=0.7):
        """复制差异较大的图片到输出文件夹"""
        print(f"\n📁 正在复制差异图片到: {output_folder}")
        
        copied_count = 0
        for img_path in results['dissimilar_images']:
            try:
                # 获取相似度分数
                score = results['similarity_scores'][img_path]['overall']
                if score < threshold:
                    # 复制文件
                    dest_path = os.path.join(output_folder, os.path.basename(img_path))
                    shutil.copy2(img_path, dest_path)
                    copied_count += 1
                    print(f"复制: {os.path.basename(img_path)} (相似度: {score:.3f})")
            except Exception as e:
                print(f"复制文件失败 {img_path}: {str(e)}")
        
        print(f"成功复制 {copied_count} 张差异较大的图片")
    
    def save_report(self, results, output_folder):
        """保存分析报告"""
        # 保存JSON格式的详细报告
        json_path = os.path.join(output_folder, 'similarity_analysis_report.json')
        with open(json_path, 'w', encoding='utf-8') as f:
            json.dump(results, f, ensure_ascii=False, indent=2)
        
        # 保存文本格式的摘要报告
        txt_path = os.path.join(output_folder, 'similarity_analysis_summary.txt')
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write("图片相似性分析报告\n")
            f.write("="*60 + "\n")
            f.write(f"分析时间: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n\n")
            
            stats = results['analysis_stats']
            f.write(f"📊 分析摘要\n")
            f.write(f"总目标图片数量: {stats['total_target_images']}\n")
            f.write(f"参考图片数量: {stats['reference_count']}\n")
            f.write(f"差异较大的图片数量: {stats['dissimilar_count']}\n\n")
            
            f.write(f"🔍 相似度分布:\n")
            for group, count in stats['similarity_distribution'].items():
                if count > 0:
                    group_name = {
                        'very_similar': '高度相似 (≥95%)',
                        'similar': '相似 (85%-95%)',
                        'somewhat_similar': '有些相似 (70%-85%)',
                        'dissimilar': '差异较大 (<70%)'
                    }.get(group, group)
                    f.write(f"  {group_name}: {count} 张\n")
            
            if results['dissimilar_images']:
                f.write(f"\n❌ 差异较大的图片列表:\n")
                for img_path in results['dissimilar_images']:
                    score = results['similarity_scores'][img_path]['overall']
                    f.write(f"- {os.path.basename(img_path)} (相似度: {score:.3f})\n")

def main():
    """主函数"""
    # 设置您的具体路径
    TARGET_FOLDER = r"C:\Users\Administrator\Downloads\骑手筛选\1-2q27"       # 要比较的图片
    REFERENCE_FOLDER = r"C:\Users\Administrator\Downloads\骑手筛选\ref"       # 参考图片
    OUTPUT_FOLDER = r"C:\Users\Administrator\Downloads\骑手筛选\difference"   # 差异图片输出
    
    # 相似度阈值（0-1之间，数值越低表示差异越大）
    SIMILARITY_THRESHOLD = 0.15

    
    try:
        # 创建分析器实例
        analyzer = ImageSimilarityAnalyzer(
            hash_size=8,
            highfreq_factor=4,
            image_scale=64
        )
        
        # 执行分析
        results = analyzer.analyze_similarity(
            target_folder=TARGET_FOLDER,
            reference_folder=REFERENCE_FOLDER,
            output_folder=OUTPUT_FOLDER,
            threshold=SIMILARITY_THRESHOLD
        )
        
    except KeyboardInterrupt:
        print("\n程序被用户中断")
    except Exception as e:
        print(f"程序执行出错: {str(e)}")
        import traceback
        traceback.print_exc()

if __name__ == '__main__':
    main()
# Out:
# ============================================================
# 图片相似性分析工具 - 开始分析
# ============================================================
#
# 获取参考图片 (C:\Users\Administrator\Downloads\骑手筛选\ref)...
# 找到 6 张参考图片
#
# 获取目标图片 (C:\Users\Administrator\Downloads\骑手筛选\1-2q27)...
# 找到 253 张目标图片
#
# 计算参考图片哈希值...
# 处理参考图片 1/6: 11_q27_初心_在活动开始之际_请上传您的核实骑手身份的截图_52D7D40A_A0C8_45EE_BFEC_D1FDC1.jpeg
# 处理参考图片 2/6: 19_q27_晚风_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110238_com.png
# 处理参考图片 3/6: 1_q27_123木头人_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_102702.jpg
# 处理参考图片 4/6: 4_q27_千与千寻_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_102709.jpg
# 处理参考图片 5/6: 56_q27_乌唧唧_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7549.jpeg
# 处理参考图片 6/6: 9_q27_芝士_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7877.jpeg
#
# 计算目标图片哈希值...
# 处理目标图片 1/253: 100_q27_筱筱骏骏_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758074298013.jpg
# 处理目标图片 2/253: 101_q27_夏虫不可语冰_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110943_com.jpg
# 处理目标图片 3/253: 102_q27_青雉_在活动开始之际_请上传您的核实骑手身份的截图_IMG_3330.jpeg
# 处理目标图片 4/253: 103_q27___在活动开始之际_请上传您的核实骑手身份的截图_BD29744B_C024_47A1_92B4_6F01AA.jpeg
# 处理目标图片 5/253: 104_q27_momo_在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1758005595277.jpg
# 处理目标图片 6/253: 105_q27_1_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_083112.jpg
# 处理目标图片 7/253: 106_q27_oi_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_111013.jpg
# 处理目标图片 8/253: 107_q27_东南_在活动开始之际_请上传您的核实骑手身份的截图_comment_b61ce604db568a0c96fd83.png
# 处理目标图片 9/253: 108_q27_搁浅_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_01_44_48.jpg
# 处理目标图片 10/253: 109_q27_en_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6019.png
# 处理目标图片 11/253: 10_q27_一笑而过__在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17580761552881040g2.jpg
# 处理目标图片 12/253: 110_q27___在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_111101.jpg
# 处理目标图片 13/253: 110_q27___在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1752821593729.jpg
# 处理目标图片 14/253: 111_q27_源心自有光明月_在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1758023196570.jpg
# 处理目标图片 15/253: 112_q27_克卜勒的小公主_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1754975391468.jpg
# 处理目标图片 16/253: 113_q27_无敌了_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078674521.jpg
# 处理目标图片 17/253: 114_q27_nono_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1757340465186.jpg
# 处理目标图片 18/253: 115_q27_LYH_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6896.jpeg
# 处理目标图片 19/253: 116_q27_贺之_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_1758078685238_edit_.jpg
# 处理目标图片 20/253: 117_q27_繁星雨露_在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1757930569724.jpg
# 处理目标图片 21/253: 118_q27_前正_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_09_06_16.jpg
# 处理目标图片 22/253: 119_q27_时瑾_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_14_00_39_37.jpg
# 处理目标图片 23/253: 11_q27_初心_在活动开始之际_请上传您的核实骑手身份的截图_52D7D40A_A0C8_45EE_BFEC_D1FDC1.jpeg
# 处理目标图片 24/253: 121_q27_囡_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758078705136.jpg
# 处理目标图片 25/253: 122_q27_L_在活动开始之际_请上传您的核实骑手身份的截图_IMG_4797.png
# 处理目标图片 26/253: 123_q27_好酸一女的_在活动开始之际_请上传您的核实骑手身份的截图_IMG_2772.png
# 处理目标图片 27/253: 124_q27_小筱HPY_在活动开始之际_请上传您的核实骑手身份的截图_IMG_4317.jpeg
# 处理目标图片 28/253: 125_q27_烟雨江南_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17580785725911040g2.jpg
# 处理目标图片 29/253: 126_q27_一心只为一人_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_12_20_38_00.jpg
# 处理目标图片 30/253: 127_q27_q_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_090311.jpg
# 处理目标图片 31/253: 128_q27_不吃榴莲_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078784096.jpg
# 处理目标图片 32/253: 129_q27_仪崽又困喽_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_13_03.jpg
# 处理目标图片 33/253: 12_q27_Z_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0757.png
# 处理目标图片 34/253: 130_q27_南风知我意__在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078787530.jpg
# 处理目标图片 35/253: 131_q27_梦_早起版__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_09_26.jpg
# 处理目标图片 36/253: 132_q27_洛_辰_在活动开始之际_请上传您的核实骑手身份的截图_Du_1753939310872.jpg
# 处理目标图片 37/253: 133_q27___在活动开始之际_请上传您的核实骑手身份的截图_IMG_4287.jpeg
# 处理目标图片 38/253: 134_q27_Deson_在活动开始之际_请上传您的核实骑手身份的截图_Camera_1040g3k031mh0uhv9lm6g5o.jpg
# 处理目标图片 39/253: 135_q27_随性_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_13_14.jpg
# 处理目标图片 40/253: 136_q27_爱生活丶爱yz_在活动开始之际_请上传您的核实骑手身份的截图_76ba2c23_4ef8_46a2_b517_c2883e.png
# 处理目标图片 41/253: 137_q27_小派_在活动开始之际_请上传您的核实骑手身份的截图_1758078567918.jpg
# 处理目标图片 42/253: 138_q27_想吹吹海风_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758077249010.jpg
# 处理目标图片 43/253: 139_q27__乔__在活动开始之际_请上传您的核实骑手身份的截图_IMG_1353.png
# 处理目标图片 44/253: 13_q27_z_在活动开始之际_请上传您的核实骑手身份的截图_634a1ef8cb703b4c8f2d2d3c44981c.jpeg
# 处理目标图片 45/253: 140_q27_奇_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250611_171509.jpg
# 处理目标图片 46/253: 141_q27_c_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0056.jpeg
# 处理目标图片 47/253: 142_q27___在活动开始之际_请上传您的核实骑手身份的截图_9267cf23b455bdcd89a0ea840eb596.jpeg
# 处理目标图片 48/253: 143_q27_实无缘_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078690821.jpg
# 处理目标图片 49/253: 144_q27___在活动开始之际_请上传您的核实骑手身份的截图_D8BE79A9_D675_4B00_9EED_317C4B.png
# 处理目标图片 50/253: 145_q27_An_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0670.png
# 处理目标图片 51/253: 146_q27_善乐意_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078832225_edit_536.jpg
# 处理目标图片 52/253: 147_q27_这世界有你们无畏_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758078751225.jpg
# 处理目标图片 53/253: 148_q27_滔滔不绝_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6021.png
# 处理目标图片 54/253: 149_q27_sweat_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_081636_com.jpg
# 处理目标图片 55/253: 14_q27___在活动开始之际_请上传您的核实骑手身份的截图_IMG_5522.jpeg
# 处理目标图片 56/253: 150_q27___在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_0913_044549.png
# 处理目标图片 57/253: 151_q27_Mr_Beard__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_11_00_01_30.jpg
# 处理目标图片 58/253: 152_q27_麦兜吃不胖_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078896448.jpg
# 处理目标图片 59/253: 153_q27_耀眼_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758078740157.jpg
# 处理目标图片 60/253: 154_q27_落尘_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_14_26.jpg
# 处理目标图片 61/253: 155_q27_小麦姐姐_在活动开始之际_请上传您的核实骑手身份的截图_MEITU_20250917_111524276.jpg
# 处理目标图片 62/253: 156_q27_明_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_13_38.jpg
# 处理目标图片 63/253: 157_q27_某人是猪_在活动开始之际_请上传您的核实骑手身份的截图_E0A3F287_CD1B_45B2_95D4_50B36F.jpeg
# 处理目标图片 64/253: 158_q27_柚子_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_07_52.jpg
# 处理目标图片 65/253: 159_q27_洞洞幺_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6699.jpeg
# 处理目标图片 66/253: 15_q27_遇猫__在活动开始之际_请上传您的核实骑手身份的截图_IMG_4747.png
# 处理目标图片 67/253: 160_q27_鄂尔多斯酒金甘草15248427754_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_111611.jpg
# 处理目标图片 68/253: 161_q27_安然_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6022.png
# 处理目标图片 69/253: 162_q27_蓝猫_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0189.jpeg
# 处理目标图片 70/253: 163_q27_东方_在活动开始之际_请上传您的核实骑手身份的截图_IMG20250916155946.jpg
# 处理目标图片 71/253: 164_q27_睡个懒觉__在活动开始之际_请上传您的核实骑手身份的截图_IMG_0452.jpeg
# 处理目标图片 72/253: 165_q27_只一人_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_08_20_19.jpg
# 处理目标图片 73/253: 166_q27_半生流离_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_16_24.jpg
# 处理目标图片 74/253: 167_q27_一个平平无奇的韭菜罢了_在活动开始之际_请上传您的核实骑手身份的截图_IMG_5333.png
# 处理目标图片 75/253: 168_q27_130_在活动开始之际_请上传您的核实骑手身份的截图_IMG_2690.jpeg
# 处理目标图片 76/253: 169_q27__好运来_在活动开始之际_请上传您的核实骑手身份的截图_feedback_Screenshot_2025_09_17.jpg
# 处理目标图片 77/253: 16_q27_安安呀_在活动开始之际_请上传您的核实骑手身份的截图_1225B6DFCBA6ECE9A51729819BEF66.png
# 处理目标图片 78/253: 170_q27_小小鱼__在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078948350.jpg
# 处理目标图片 79/253: 171_q27_A_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_0917_111407.png
# 处理目标图片 80/253: 172_q27_Jr_在活动开始之际_请上传您的核实骑手身份的截图_IMG_5258.png
# 处理目标图片 81/253: 173_q27___在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250823_223521.jpg
# 处理目标图片 82/253: 174_q27_风_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078841802.jpg
# 处理目标图片 83/253: 175_q27_deja_vu_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_17_07.jpg
# 处理目标图片 84/253: 176_q27_裕幸_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_111814.jpg
# 处理目标图片 85/253: 177_q27_不要再熬夜了_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_06_19_20_42_06.jpg
# 处理目标图片 86/253: 178_q27___在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_16_17_56_51.jpg
# 处理目标图片 87/253: 179_q27_kiss_轩__在活动开始之际_请上传您的核实骑手身份的截图_2bc39c57de6ac7aa3e23599a420816.jpeg
# 处理目标图片 88/253: 17_q27__七秒記憶__在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078131578.jpg
# 处理目标图片 89/253: 180_q27_畲_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_111833.jpg
# 处理目标图片 90/253: 181_q27_名字只是代号_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758079087479.jpg
# 处理目标图片 91/253: 182_q27_柏然_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6023.jpeg
# 处理目标图片 92/253: 183_q27_娜_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_13_03.jpg
# 处理目标图片 93/253: 184_q27__简_心__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_111948_me_.jpg
# 处理目标图片 94/253: 185_q27_大人_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0189.jpeg
# 处理目标图片 95/253: 186_q27_春天_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_10_56_29.jpg
# 处理目标图片 96/253: 187_q27_海洋局的不犄角_SHUNLI版_在活动开始之际_请上传您的核实骑手身份的截图_image.jpg
# 处理目标图片 97/253: 188_q27_momo_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250912_173649.jpg
# 处理目标图片 98/253: 189_q27_顾池_在活动开始之际_请上传您的核实骑手身份的截图_1758079233356.png
# 处理目标图片 99/253: 18_q27_岚玉_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1105.jpeg
# 处理目标图片 100/253: 190_q27_十点就睡_在活动开始之际_请上传您的核实骑手身份的截图_IMG_4545.jpeg
# 处理目标图片 101/253: 191_q27___在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_112046.jpg
# 处理目标图片 102/253: 192_q27_奶凶_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_21_23.jpg
# 处理目标图片 103/253: 193_q27_棱角_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758079202160.jpg
# 处理目标图片 104/253: 194_q27__LTG_b_在活动开始之际_请上传您的核实骑手身份的截图_761FB31E_AC4D_4AE0_BD7F_03C941.jpeg
# 处理目标图片 105/253: 195_q27_心想事_陈先生_在活动开始之际_请上传您的核实骑手身份的截图_微信图片_20250917112204_19_395.jpg
# 处理目标图片 106/253: 196_q27_一路向前_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758079134815.jpg
# 处理目标图片 107/253: 197_q27_33_在活动开始之际_请上传您的核实骑手身份的截图_微信图片_2025_07_19_150557_847.jpg
# 处理目标图片 108/253: 198_q27_叭叭叭路路通_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758079087479.jpg
# 处理目标图片 109/253: 199_q27_初皖_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_112441.jpg
# 处理目标图片 110/253: 19_q27_晚风_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110238_com.png
# 处理目标图片 111/253: 1_q27_123木头人_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_102702.jpg
# 处理目标图片 112/253: 200_q27_clown_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758079537582.jpg
# 处理目标图片 113/253: 201_q27_唔通_在活动开始之际_请上传您的核实骑手身份的截图_FDCD6573B1669AFF9012B11313C14E.png
# 处理目标图片 114/253: 202_q27_汪嘉炜_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_112555_com.jpg
# 处理目标图片 115/253: 203_q27_otk_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_112754_me_.jpg
# 处理目标图片 116/253: 204_q27___在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_112856.jpg
# 处理目标图片 117/253: 205_q27_L_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758079690912.jpg
# 处理目标图片 118/253: 206_q27_安生_在活动开始之际_请上传您的核实骑手身份的截图_IMG_5914.jpeg
# 处理目标图片 119/253: 207_q27_反派_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7431.png
# 处理目标图片 120/253: 209_q27_向上__在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_112956.jpg
# 处理目标图片 121/253: 20_q27_您也太棒了_在活动开始之际_请上传您的核实骑手身份的截图_IMG_4186.jpeg
# 处理目标图片 122/253: 210_q27_小梦_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758079974151.jpg
# 处理目标图片 123/253: 211_q27_金金_在活动开始之际_请上传您的核实骑手身份的截图_D2D16C61_D12C_48BB_9A62_6BFB9C.jpeg
# 处理目标图片 124/253: 212_q27_风止_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1700.jpeg
# 处理目标图片 125/253: 213_q27_腐苏_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0477.jpeg
# 处理目标图片 126/253: 214_q27_星星_在活动开始之际_请上传您的核实骑手身份的截图_89EA9261_36BB_4F82_9227_646B49.jpeg
# 处理目标图片 127/253: 215_q27_无双_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_113941.jpg
# 处理目标图片 128/253: 216_q27_是海不是山海_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758080915335.jpg
# 处理目标图片 129/253: 217_q27_满天星__在活动开始之际_请上传您的核实骑手身份的截图_IMG_7256.jpeg
# 处理目标图片 130/253: 218_q27_琳达_摆烂版__在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758080937095.jpg
# 处理目标图片 131/253: 219_q27___在活动开始之际_请上传您的核实骑手身份的截图_mmexport1757220550074.jpg
# 处理目标图片 132/253: 21_q27_小雪_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758077816136.jpg
# 处理目标图片 133/253: 220_q27_沐子_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758081117622.jpg
# 处理目标图片 134/253: 221_q27_浅池_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_115359.jpg
# 处理目标图片 135/253: 222_q27_今早起来吃_在活动开始之际_请上传您的核实骑手身份的截图_FADBBC27_FD83_45F9_8634_2267A6.jpeg
# 处理目标图片 136/253: 223_q27_玖玖_在活动开始之际_请上传您的核实骑手身份的截图_IMG_2993.jpeg
# 处理目标图片 137/253: 224_q27_如痴_在活动开始之际_请上传您的核实骑手身份的截图_46C316DE_0639_4F2F_A59D_C6D6D0.jpeg
# 处理目标图片 138/253: 225_q27_璞海_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758004717576.jpg
# 处理目标图片 139/253: 226_q27_山野半雾归_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250915_181438.jpg
# 处理目标图片 140/253: 227_q27_您也太秀了_在活动开始之际_请上传您的核实骑手身份的截图_IMG_9129.png
# 处理目标图片 141/253: 228_q27_落叶_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250915_225532.jpg
# 处理目标图片 142/253: 229_q27_198_9412_在活动开始之际_请上传您的核实骑手身份的截图_IMG20250917121243.jpg
# 处理目标图片 143/253: 22_q27_曲_憶人_在活动开始之际_请上传您的核实骑手身份的截图_微信图片_2025_07_18_110928_595.png
# 处理目标图片 144/253: 230_q27_渝__在活动开始之际_请上传您的核实骑手身份的截图_Image_1758082304720.jpg
# 处理目标图片 145/253: 231_q27_太_在活动开始之际_请上传您的核实骑手身份的截图_share_image_1758082553453.jpeg
# 处理目标图片 146/253: 232_q27_123_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_121651.jpg
# 处理目标图片 147/253: 233_q27_晨_大展宏图_中大奖__在活动开始之际_请上传您的核实骑手身份的截图_IMG_3239.jpeg
# 处理目标图片 148/253: 234_q27_否极泰来_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_12_21_28.jpg
# 处理目标图片 149/253: 235_q27_只_嘿_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758082787485.jpg
# 处理目标图片 150/253: 236_q27_z_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758031133900.jpg
# 处理目标图片 151/253: 238_q27_琉璃_在活动开始之际_请上传您的核实骑手身份的截图_IMG20250405183550.jpg
# 处理目标图片 152/253: 23_q27_初梦_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0760.png
# 处理目标图片 153/253: 240_q27_幸福来敲门_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6364.png
# 处理目标图片 154/253: 243_q27_G_10_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1755935226167.jpg
# 处理目标图片 155/253: 244_q27_努仔_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758084314873.jpg
# 处理目标图片 156/253: 246_q27_五星红旗_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1755938114452.jpg
# 处理目标图片 157/253: 247_q27_小_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_125020.jpg
# 处理目标图片 158/253: 248_q27_B_5_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1755935223277.jpg
# 处理目标图片 159/253: 249_q27_Y_在活动开始之际_请上传您的核实骑手身份的截图_share_944943ca238a2676bec180dc.png
# 处理目标图片 160/253: 24_q27_孤独的猫_在活动开始之际_请上传您的核实骑手身份的截图_997C45C8_A267_4109_84D0_B00CA8.png
# 处理目标图片 161/253: 251_q27_J_13_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1755935219793.jpg
# 处理目标图片 162/253: 252_q27_H_11_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1755935226167.jpg
# 处理目标图片 163/253: 253_q27_胡言不乱语_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_08_20_09_11_41.jpg
# 处理目标图片 164/253: 255_q27_靓_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758030483451.jpg
# 处理目标图片 165/253: 256_q27_拾光_在活动开始之际_请上传您的核实骑手身份的截图_0057834c3f4ffe59e1d0250afd5a19.jpeg
# 处理目标图片 166/253: 257_q27_仰望_在活动开始之际_请上传您的核实骑手身份的截图_D0DA248D_C3DA_4B4A_B9F9_643AEF.jpeg
# 处理目标图片 167/253: 258_q27_恋恋小鸢_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_131337.jpg
# 处理目标图片 168/253: 259_q27_暖瞳_在活动开始之际_请上传您的核实骑手身份的截图_1758087251627.jpeg
# 处理目标图片 169/253: 25_q27___在活动开始之际_请上传您的核实骑手身份的截图_mmexport1757762659163.jpeg
# 处理目标图片 170/253: 260_q27_花_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1932.jpeg
# 处理目标图片 171/253: 261_q27_胖胖_在活动开始之际_请上传您的核实骑手身份的截图_88B9D6BA_B5A0_43AD_BD13_F7F09F.jpeg
# 处理目标图片 172/253: 262_q27_循迹_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758095759440.jpg
# 处理目标图片 173/253: 263_q27_蒋长宁_在活动开始之际_请上传您的核实骑手身份的截图_Image_285513423852555.png
# 处理目标图片 174/253: 26_q27_y_在活动开始之际_请上传您的核实骑手身份的截图__sf_shoot_new_78282073.jpg
# 处理目标图片 175/253: 27_q27_无是_在活动开始之际_请上传您的核实骑手身份的截图_Image_1758078265688.png
# 处理目标图片 176/253: 28_q27_正_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7547.jpeg
# 处理目标图片 177/253: 29_q27_Crosser_在活动开始之际_请上传您的核实骑手身份的截图_Image_130541634627699.png
# 处理目标图片 178/253: 2_q27_小哈_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_10_27_18.jpg
# 处理目标图片 179/253: 30_q27_We_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_04_17.jpg
# 处理目标图片 180/253: 31_q27_爱世界_在活动开始之际_请上传您的核实骑手身份的截图_IMG_3580.jpeg
# 处理目标图片 181/253: 32_q27_Leeee_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1094.jpeg
# 处理目标图片 182/253: 34_q27_左右__在活动开始之际_请上传您的核实骑手身份的截图_819c2987e4d740a43fdbf7984efefc.jpeg
# 处理目标图片 183/253: 35_q27_阿泽__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_06_21.jpg
# 处理目标图片 184/253: 36_q27_辛弃疾_在活动开始之际_请上传您的核实骑手身份的截图_1758076152075.jpg
# 处理目标图片 185/253: 37_q27_龙_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110626.jpg
# 处理目标图片 186/253: 38_q27_Moonlight_在活动开始之际_请上传您的核实骑手身份的截图_1758077991425_edit_17100851726.jpg
# 处理目标图片 187/253: 39_q27_丸子布丁_在活动开始之际_请上传您的核实骑手身份的截图_208CFC6B_E70B_4D71_891A_A51697.jpeg
# 处理目标图片 188/253: 3_q27_三杯冰美式_在活动开始之际_请上传您的核实骑手身份的截图_B2CBBC77_CD02_4DD2_BA13_F763F1.jpeg
# 处理目标图片 189/253: 40_q27_shmily_在活动开始之际_请上传您的核实骑手身份的截图_IMG_4641.jpeg
# 处理目标图片 190/253: 41_q27_于蕊来暖气水管批发18646609077_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110649.png
# 处理目标图片 191/253: 42_q27_小5_在活动开始之际_请上传您的核实骑手身份的截图_image.jpg
# 处理目标图片 192/253: 43_q27_太贵了_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110643.jpg
# 处理目标图片 193/253: 44_q27_林夕_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250624_205810.jpg
# 处理目标图片 194/253: 45_q27___在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_06_53.jpg
# 处理目标图片 195/253: 46_q27_哦我还放不放假放假_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_00_42_11.jpg
# 处理目标图片 196/253: 47_q27_Naive_ghost_在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1755603096802.jpg
# 处理目标图片 197/253: 48_q27_番茄炒蛋_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1196.jpeg
# 处理目标图片 198/253: 49_q27_秃顶老头__在活动开始之际_请上传您的核实骑手身份的截图_AAA6D02D_ABEC_4C42_9A72_0007F4.jpeg
# 处理目标图片 199/253: 4_q27_千与千寻_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_102709.jpg
# 处理目标图片 200/253: 50_q27_迷雾__在活动开始之际_请上传您的核实骑手身份的截图_IMG_4713.jpeg
# 处理目标图片 201/253: 51_q27_ccccccc_在活动开始之际_请上传您的核实骑手身份的截图_image.jpg
# 处理目标图片 202/253: 52_q27_Moii_在活动开始之际_请上传您的核实骑手身份的截图_IMG_2273.jpeg
# 处理目标图片 203/253: 53_q27_wink_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_07_14.jpg
# 处理目标图片 204/253: 54_q27_飘啊飘_在活动开始之际_请上传您的核实骑手身份的截图_promphoto_1758069467791.jpg
# 处理目标图片 205/253: 55_q27_清风_在活动开始之际_请上传您的核实骑手身份的截图_1758043432993.jpeg
# 处理目标图片 206/253: 56_q27_乌唧唧_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7549.jpeg
# 处理目标图片 207/253: 57_q27_细沙_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_07_36.jpg
# 处理目标图片 208/253: 58_q27_Dawn_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17580784371861040g0.jpg
# 处理目标图片 209/253: 59_q27_ldx_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110750_com.jpg
# 处理目标图片 210/253: 5_q27_六月_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_102859.jpg
# 处理目标图片 211/253: 60_q27_不放辣_在活动开始之际_请上传您的核实骑手身份的截图_913410DD_164C_41ED_8293_3DC4A7.jpeg
# 处理目标图片 212/253: 62_q27_悠然自得_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078186214.jpg
# 处理目标图片 213/253: 63_q27_芒果_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110757.jpg
# 处理目标图片 214/253: 64_q27__LZY__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_07_56.jpg
# 处理目标图片 215/253: 65_q27_懒懒发财记__在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110320.jpg
# 处理目标图片 216/253: 66_q27_欧可_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17580784733231040g0.jpg
# 处理目标图片 217/253: 67_q27_爱吃鲅鱼饺_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078492302.jpg
# 处理目标图片 218/253: 68_q27_626_在活动开始之际_请上传您的核实骑手身份的截图_IMG_9790.jpeg
# 处理目标图片 219/253: 69_q27_木可_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_175807847648901027e.jpg
# 处理目标图片 220/253: 6_q27___在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758076154362.jpg
# 处理目标图片 221/253: 70_q27_红叶高原_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_11_08_15.jpg
# 处理目标图片 222/253: 72_q27_小新334_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110805.jpg
# 处理目标图片 223/253: 73_q27__i_在活动开始之际_请上传您的核实骑手身份的截图_IMG_2146.jpeg
# 处理目标图片 224/253: 74_q27_Breeze_在活动开始之际_请上传您的核实骑手身份的截图_600890a276ae4a74c68eabc6e24734.jpeg
# 处理目标图片 225/253: 75_q27_coco_在活动开始之际_请上传您的核实骑手身份的截图_IMG_1871.jpeg
# 处理目标图片 226/253: 76_q27_鱼儿_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110823.jpg
# 处理目标图片 227/253: 77_q27_晚安_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110841.jpg
# 处理目标图片 228/253: 78_q27_13jfjd_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_00_42_11.jpg
# 处理目标图片 229/253: 79_q27_xk_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078524317.jpg
# 处理目标图片 230/253: 7_q27_绾_在活动开始之际_请上传您的核实骑手身份的截图_IMG_0431.png
# 处理目标图片 231/253: 80_q27_开开心心每一天_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078336911.jpg
# 处理目标图片 232/253: 81_q27___在活动开始之际_请上传您的核实骑手身份的截图_image.jpg
# 处理目标图片 233/253: 82_q27_Z_在活动开始之际_请上传您的核实骑手身份的截图_13E7743D_531E_4456_B687_5B1EBA.jpeg
# 处理目标图片 234/253: 83_q27_光芒_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078542551.jpg
# 处理目标图片 235/253: 84_q27_攒够100万就退休_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078514351.jpg
# 处理目标图片 236/253: 85_q27_G_uo__在活动开始之际_请上传您的核实骑手身份的截图_IMG_6459.jpeg
# 处理目标图片 237/253: 86_q27_睡觉_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_09_06_16.jpg
# 处理目标图片 238/253: 87_q27_W__在活动开始之际_请上传您的核实骑手身份的截图_2222.png
# 处理目标图片 239/253: 88_q27_ni_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110754.jpg
# 处理目标图片 240/253: 89_q27_上好佳kk_在活动开始之际_请上传您的核实骑手身份的截图_IMG_5726.png
# 处理目标图片 241/253: 89_q27_上好佳kk_在活动开始之际_请上传您的核实骑手身份的截图_IMG_5738.png
# 处理目标图片 242/253: 8_q27_zZ_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_10_31_51.jpg
# 处理目标图片 243/253: 90_q27_如果_可以_在活动开始之际_请上传您的核实骑手身份的截图_image_editor_1758078087500.jpg
# 处理目标图片 244/253: 91_q27_茶茶_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758078565529.jpg
# 处理目标图片 245/253: 92_q27_OPpam_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6771.jpeg
# 处理目标图片 246/253: 93_q27___在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17580783682311040g2.jpg
# 处理目标图片 247/253: 94_q27_神鹰黑手哥_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_110649.png
# 处理目标图片 248/253: 95_q27___在活动开始之际_请上传您的核实骑手身份的截图_mmexport1702821430274.jpg
# 处理目标图片 249/253: 96_q27_花朵朵_在活动开始之际_请上传您的核实骑手身份的截图_Camera_XHS_17555029527951040g0.jpg
# 处理目标图片 250/253: 97_q27_YY_在活动开始之际_请上传您的核实骑手身份的截图_Camera_1040g3k031g7df48c1s505p.jpg
# 处理目标图片 251/253: 98_q27_无解_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758076419826.jpg
# 处理目标图片 252/253: 99_q27_proud_boy_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_01_56_22.jpg
# 处理目标图片 253/253: 9_q27_芝士_在活动开始之际_请上传您的核实骑手身份的截图_IMG_7877.jpeg
#
# 分析图片相似性...
#
# 📊 分析结果摘要
# ----------------------------------------
# 总目标图片数量: 253
# 参考图片数量: 6
# 差异较大的图片数量: 253
#
# 🔍 相似度分布:
#   差异较大 (<70%): 253 张
#
# ❌ 差异较大的图片:
#   1. 100_q27_筱筱骏骏_在活动开始之际_请上传您的核实骑手身份的截图_mmexport1758074298013.jpg (相似度: 0.183)
#   2. 101_q27_夏虫不可语冰_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_110943_com.jpg (相似度: 0.315)
#   3. 102_q27_青雉_在活动开始之际_请上传您的核实骑手身份的截图_IMG_3330.jpeg (相似度: 0.276)
#   4. 103_q27___在活动开始之际_请上传您的核实骑手身份的截图_BD29744B_C024_47A1_92B4_6F01AA.jpeg (相似度: 0.205)
#   5. 104_q27_momo_在活动开始之际_请上传您的核实骑手身份的截图_wx_camera_1758005595277.jpg (相似度: 0.165)
#   6. 105_q27_1_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_20250917_083112.jpg (相似度: 0.193)
#   7. 106_q27_oi_在活动开始之际_请上传您的核实骑手身份的截图_IMG_20250917_111013.jpg (相似度: 0.357)
#   8. 107_q27_东南_在活动开始之际_请上传您的核实骑手身份的截图_comment_b61ce604db568a0c96fd83.png (相似度: 0.356)
#   9. 108_q27_搁浅_在活动开始之际_请上传您的核实骑手身份的截图_Screenshot_2025_09_17_01_44_48.jpg (相似度: 0.184)
#   10. 109_q27_en_在活动开始之际_请上传您的核实骑手身份的截图_IMG_6019.png (相似度: 0.246)
#   ... 还有 243 张
#
# 📁 正在复制差异图片到: C:\Users\Administrator\Downloads\骑手筛选\difference
# 复制: 163_q27_东方_在活动开始之际_请上传您的核实骑手身份的截图_IMG20250916155946.jpg (相似度: 0.133)
# 复制: 219_q27___在活动开始之际_请上传您的核实骑手身份的截图_mmexport1757220550074.jpg (相似度: 0.144)
# 成功复制 2 张差异较大的图片
#
# ============================================================
# 分析完成！
# 差异图片已保存到: C:\Users\Administrator\Downloads\骑手筛选\difference
# ============================================================
